# %%
# import required packages and read data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# abcd

# %%
file_path = r"C:\Users\user\OneDrive\NareshIT\DataScience\EDA\Visadataset.csv"
visa_df = pd.read_csv(file_path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
p_wage = visa_df[['prevailing_wage']]
wage_count=p_wage.count()
wage_mean=round(p_wage.mean(),2)
wage_median=round(p_wage.median(), 2)
wage_max = round(p_wage.max(), 2)
wage_min = round(p_wage.min(), 2)

list1 = [wage_count, wage_mean, wage_median, wage_max, wage_min]
index_list = ['count', 'max', 'min', 'mean', 'median']
pd.DataFrame(list1, columns=

# %%
num_cols=visa_df.select_dtypes(exclude='object').columns
dict1={}
for i in num_cols:
    wage_count=visa_df[i].count()
    wage_mean=round(visa_df[i].mean(),2)
    wage_median=round(visa_df[i].median(), 2)
    wage_max = round(visa_df[i].max(), 2)
    wage_min = round(visa_df[i].min(), 2)
    
    list1 = [wage_count, wage_mean, wage_median, wage_max, wage_min]
    dict1[i]=list1
index_list = ['count', 'max', 'min', 'mean', 'median']
number_df=pd.DataFrame(dict1, index=index_list)
number_df.to_csv('number_visa.csv')
number_df
# Out:
#         no_of_employees  yr_of_estab  prevailing_wage
# count          25480.00     25480.00         25480.00
# max             5667.04      1979.41         74455.81
# min             2109.00      1997.00         70308.21
# mean          602069.00      2016.00        319210.27
# median           -26.00      1800.00             2.14

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %%
#value = number_df['no_of_employees'].value_counts()
value = visa_df['continent'].value_counts().to_list()
ax=value.plot(kind='bar')
ax.bar_label(ax.containers[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 3
#       1 #value = number_df['no_of_employees'].value_counts()
#       2 value = visa_df['no_of_employees'].value_counts().to_list()
# ----> 3 ax=value.plot(kind='bar')
#       4 ax.bar_label(ax.containers[0])
#
# AttributeError: 'list' object has no attribute 'plot'

# %%
# Importing numpy module

# %%
p_wage = visa_df['prevailing_wage']
np.mean(p_wage)
np.median(p_wage)
# Out:
# 74455.81459209183

# %% [markdown]
# **percentile-Quantile**
# - In the numpy package we have np.percentail() np.quatile()
#
# - percentile: if you want to 25p 25
#
# -

# %%
num_cols=visa_df.select_dtypes(exclude='object').columns
dict1={}
for i in num_cols:
    wage_count=visa_df[i].count()
    wage_mean=round(visa_df[i].mean(),2)
    wage_median=round(visa_df[i].median(), 2)
    wage_max = round(visa_df[i].max(), 2)
    wage_min = round(visa_df[i].min(), 2)
    wage_std = round(visa_df[i].std(), 2)
    wage_25p = round(np.percentile(visa_df[i], 25), 2)
    wage_50p = round(np.percentile(visa_df[i], 50), 2)
    wage_75p = round(np.percentile(visa_df[i], 75), 2)
    list1 = [wage_count, wage_mean, wage_median, 
             wage_max, wage_min, wage_std, wage_25p,
             wage_50p, wage_75p]
    dict1[i]=list1
    
index_list = ['count', 'mean', 'median','max', 'min', 'std', '25%',
              '50%' ,'75%']
number_df=pd.DataFrame(dict1, index=index_list)
number_df.to_csv('number_visa.csv')
number_df
# Out:
#         no_of_employees  yr_of_estab  prevailing_wage
# count          25480.00     25480.00         25480.00
# mean            5667.04      1979.41         74455.81
# median          2109.00      1997.00         70308.21
# max           602069.00      2016.00        319210.27
# min              -26.00      1800.00             2.14
# std            22877.93        42.37         52815.94
# 25%             1022.00      1976.00         34015.48
# 50%             2109.00      1997.00         70308.21
# 75%             3504.00      2005.00        107735.51

# %%
p_wage = visa_df['prevailing_wage']
cont_25p = len(p_wage[p_wage<np.percentile(p_wage, 25)])
cont_50p = len(p_wage[p_wage<np.percentile(p_wage, 50)])
cont_75p = len(p_wage[p_wage<np.percentile(p_wage, 75)])

l1=['Count of 25%', 'Count_of 50%', 'Count_of_75%']
l2=[cont_25p, cont_50p, cont_75p]
d1=pd.DataFrame(zip(l1,l2), columns=['Til_per', 'Count'])
plt.bar('Til_per', 'Count', data=d1)
# Out:
# <BarContainer object of 3 artists>

# %%
# strp-1: take the referrence colum frist
# apply the condition  it will provide true or flase
# Apply 
p_wage=visa_df['prevailing_wage']
p_25 = np.percentile(p_wage, 25)
con25= p_wage<p_25
visa_df[con25]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 12        EZYV13           Asia            Bachelor's                  Y
# 16        EZYV17         Europe              Master's                  Y
# 17        EZYV18           Asia              Master's                  Y
# ...          ...            ...                   ...                ...
# 25461  EZYV25462           Asia              Master's                  Y
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25473  EZYV25474           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
p_wage=visa_df['prevailing_wage']
p_50 = np.percentile(p_wage, 50)
con50= p_wage<p_50
visa_df[con50]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 6         EZYV07           Asia            Bachelor's                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 9         EZYV10         Europe             Doctorate                  Y
# 12        EZYV13           Asia            Bachelor's                  Y
# ...          ...            ...                   ...                ...
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25473  EZYV25474           Asia            Bachelor's                  Y
# 25474  EZYV25475         Africa             Doctorate                  N
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
p_wage=visa_df['prevailing_wage']
p_25 = np.percentile(p_wage, 25)
p_50 = np.percentile(p_wage, 50)
p_75 = np.percentile(p_wage, 75)
con25= p_wage<p_25
con50= p_wage<p_25
con75= p_wage<p_75
visa_df[con25&con75]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 12        EZYV13           Asia            Bachelor's                  Y
# 16        EZYV17         Europe              Master's                  Y
# 17        EZYV18           Asia              Master's                  Y
# ...          ...            ...                   ...                ...
# 25461  EZYV25462           Asia              Master's                  Y
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25473  EZYV25474           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
p_wage=visa_df['prevailing_wage']
p_25 = np.percentile(p_wage, 25)
p_50 = np.percentile(p_wage, 50)
p_75 = np.percentile(p_wage, 75)
print(p_25 , p_75)
con25= p_wage<p_25
con50= p_wage<p_50
con75= p_wage<p_75
print(con75)
visa_df[con75]
# Out:
# 34015.479999999996 107735.51250000001
# 0         True
# 1         True
# 2        False
# 3         True
# 4        False
#          ...
# 25475     True
# 25476    False
# 25477    False
# 25478     True
# 25479     True
# Name: prevailing_wage, Length: 25480, dtype: bool
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 3         EZYV04      Asia            Bachelor's                  N
# 5         EZYV06      Asia              Master's                  Y
# 6         EZYV07      Asia            Bachelor's                  N
# ...          ...       ...                   ...                ...
# 25473  EZYV25474      Asia            Bachelor's                  Y
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# ...

# %% [markdown]
# $Histogram$

# %%
- From raw data will make class intervals

- Will count the

# %%
p_wage=visa_df['prevailing_wage']
freq , interval , n = plt.hist(p_wage, bins=40)
# Out:
# <BarContainer object of 40 artists>

# %%
p_wage=visa_df['prevailing_wage']
# con1 = p_wage>freq
# con2 = p_wage>interval
# len(visa_df[cont&con2])

# %%
pd.DataFrame(zip(freq, interval), columns=[])

# %%
p_wage = visa_df[['prevailing_wage']]
wage_count=p_wage.count()
wage_mean=round(p_wage.mean(),2)
wage_median=round(p_wage.median(), 2)
wage_max = round(p_wage.max(), 2)
wage_min = round(p_wage.min(), 2)
wege_std = 

list1 = [wage_count, wage_mean, wage_median, wage_max, wage_min]
index_list = ['count', 'max', 'min', 'mean', 'median']
pd.DataFrame(list1, columns=['prevailing_wage'], index=index_list)
# Out:
#         prevailing_wage
# count          25480.00
# max            74455.81
# min            70308.21
# mean          319210.27
# median             2.14

# %%
sns.displot(visa_df['prevailing_wage']) # by defult hitrogram
sns.displot(visa_df['prevailing_wage'], kind='kde')
sns.displot(visa_df['prevailing_wage'], kind='ecdf')
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.subplot(1,3,1)
sns.distplot(visa_df['prevailing_wage']) # by defult hitrogram
plt.subplot(1,3,2)
sns.displot(visa_df['prevailing_wage'], kind='kde')
plt.subplot(1,3,3)
sns.displot(visa_df['prevailing_wage'], kind='ecdf')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_24108\682464792.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(visa_df['prevailing_wage']) # by defult hitrogram
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\user\AppData\Local\Temp\ipykernel_24108\682464792.py:5: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,3,3)
# ...
