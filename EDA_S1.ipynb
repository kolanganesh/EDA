# %%
############  Exploratory data analaysis #######
1.Pandas (Data frame analysis)
2.Numpy (Number python math package)
3.Matplot(plotting)
4.Seabron(Plotting)
5.ploty(Plotting)
6.Bokhe(plotting)

############## Machine learning ################
7.Scikit-learn (ML models will avialable)
8.Stats         (Statictical models)
#############  Deep Learning ##################
9.Tensorflow     (Developed by Google)
10.Keras
11.Torch
12.OpenCv (Computer Vision)  Opencv:sentdex you tube
####################NLP (Natural language )########
13.NLTK  (Natural language toool kit)
14.Scipy
################### GenAI ################
### Prompt Engineering ###################
15.Chat GPT is developed by OpenAI + Azure
16.MakerSuite is developed by  Google
17.Gemini is developed by Google
################### Comany Based #########
18.HuggingFace
   Tranformer Bert models
    
    
Data Analysis
ML
DL
NLP
NERT :  Transformers : T GPT
LLM  :  GenAI
        
19.ALLen NLP
########## SPL ##############

20.Random
21.Time
22.Math
23.API Flask
24.UI APPS   Streamlit

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#visa_file_path = r"C:\Users\user\OneDrive\NareshIT\DataScience\EDA\Visadataset.csv"
#pd.read_csv(file_path)
bank_file_path = r"C:\Users\user\OneDrive\NareshIT\DataScience\EDA\bank.csv"
pd.read_csv(bank_file_path, sep=',')
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# - How to create a data frame
#
# - How to add columns
#
# - How to add rows
#
# - How to arop columns
#
# - How to drop rows
#
# - How to save the dataframes

# %%
Names = ['Ramesh', 'Suresh', 'Sathish']
Age=[20,25,30]
pd.DataFrame(zip(Names, Age),)
# Out:
#          0   1
# 0   Ramesh  20
# 1   Suresh  25
# 2  Sathish  30

# %%
Names = ['Ramesh', 'Suresh', 'Sathish']
Age=[20,25,30]
df1 = pd.DataFrame(zip(Names, Age),columns=['Names', 'Age'],index=['A', 'B', 'C'])
df1
# Out:
#      Names  Age
# A   Ramesh   20
# B   Suresh   25
# C  Sathish   30

# %%
df1['Citys'] = ['Hyd', 'Bangulur', 'Chinai' ]
df1
# Out:
#      Names  Age     Citys
# A   Ramesh   20       Hyd
# B   Suresh   25  Bangulur
# C  Sathish   30    Chinai

# %%
Names = ['Ramesh', 'Suresh', 'Sathish']
Age=[20,25,30]
df1 = pd.DataFrame(zip(Names, Age),columns=['Names', 'Age'],index=[0,1,2])
df1
# Out:
#      Names  Age
# 0   Ramesh   20
# 1   Suresh   25
# 2  Sathish   30

# %%
df1.loc['A']=['Bummy','40']
df1.loc[3] = ['S', 45]
df1
# Out:
#      Names Age
# 0   Ramesh  20
# 1   Suresh  25
# 2  Sathish  30
# A    Bummy  40
# 3        S  45

# %% [markdown]
# - City clomn creating

# %%
Names = ['Ramesh', 'Suresh', 'Sathish']
Age=[20,25,30]
df1 = pd.DataFrame(zip(Names, Age),columns=['Names', 'Age'],index=[0,1,2])
df1['Citys'] = ['hyd', 'Bnl', 'chinai']
df1
# Out:
#      Names  Age   Citys
# 0   Ramesh   20     hyd
# 1   Suresh   25     Bnl
# 2  Sathish   30  chinai

# %%
# Axis =1 It reference  column
# Axis =0 It reference rows
df1.drop('Citys', axis=1, inplace=True)

# %%
df1.drop(2, axis=0, inplace=True)

# %%
df1
# Out:
#     Names  Age     g
# 0  Ramesh   20  venu
# 1  Suresh   25    45

# %%
Names = ['Ramesh', 'Suresh', 'Sathish']
Age=[20,25,30]
df1 = pd.DataFrame(zip(Names, Age),columns=['Names', 'Age'],index=[0,1,2])
df1['Citys'] = ['hyd', 'Bnl', 'chinai']
df1
# Out:
#      Names  Age   Citys
# 0   Ramesh   20     hyd
# 1   Suresh   25     Bnl
# 2  Sathish   30  chinai

# %%
df1.loc['A']=['Bummy','40', '']
df1
# Out:
#      Names Age   Citys
# 0   Ramesh  20     hyd
# 1   Suresh  25     Bnl
# 2  Sathish  30  chinai
# A    Bummy  40

# %%
df1.loc['Ramesh'] = 'Ram'

# %%
df1
# Out:
#           Names  Age   Citys
# 0        Ramesh   20     hyd
# 1        Suresh   25     Bnl
# 2       Sathish   30  chinai
# A         Bummy   40
# Ramesh      Ram  Ram     Ram

# %%
# Save df in local
df1.to_csv('ganesh.csv')

# %%
pd.read_csv('ganesh.csv')
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 pd.read_csv('ganesh.csv')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
# ...

# %%
df1.to_csv('ganesh.csv', index=False)
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df1.loc['g'] = ['venu', 45]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 df1.loc['g'] = ['venu', 45]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:849, in _LocationIndexer.__setitem__(self, key, value)
#     846 self._has_valid_setitem_indexer(key)
#     848 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 849 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1825, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1822     indexer, missing = convert_missing_indexer(indexer)
#    1824     if missing:
# -> 1825         self._setitem_with_indexer_missing(indexer, value)
#    1826         return
#    1828 if name == "loc":
#    1829     # must come after setting of missing
#
# ...

# %%
df1.loc['g'] = ['venu', 45]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 df1.loc['g'] = ['venu', 45]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:849, in _LocationIndexer.__setitem__(self, key, value)
#     846 self._has_valid_setitem_indexer(key)
#     848 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 849 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1825, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1822     indexer, missing = convert_missing_indexer(indexer)
#    1824     if missing:
# -> 1825         self._setitem_with_indexer_missing(indexer, value)
#    1826         return
#    1828 if name == "loc":
#    1829     # must come after setting of missing
#
# ...

# %%
df1
# Out:
#     Names  Age     g
# 0  Ramesh   20  venu
# 1  Suresh   25    45

# %% [markdown]
# $ Method2$
# - Creating data frame dictinary

# %%
dic1 = {'Names':['Ramesh', 'Suresh', 'Satesh'], 'Age':[20,25,30]}
dic1
# Out:
# {'Names': ['Ramesh', 'Suresh', 'Satesh'], 'Age': [20, 25, 30]}

# %%
pd.DataFrame(dic1)
# Out:
#     Names  Age
# 0  Ramesh   20
# 1  Suresh   25
# 2  Satesh   30

# %% [markdown]
# $ Method3$
# - Creating data frame emty

# %%
df1=pd.DataFrame()
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df1['']
